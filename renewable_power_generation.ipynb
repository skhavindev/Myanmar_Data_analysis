# %% [markdown]
# # Water Discharge Per Station

# %%
import pandas as pd

# Load the data with ISO-8859-1 encoding
file_path = 'GRDC_myanmar[Water_Discharge]/GRDC_myanmar/2260100_Q_Day.Cmd.txt'
data = pd.read_csv(file_path, delimiter=';', skiprows=38, encoding='ISO-8859-1')

# Combine date and time columns into a single datetime column
data['DateTime'] = pd.to_datetime(data['YYYY-MM-DD'] + ' ' + data['hh:mm'], dayfirst=True)

# Drop the original date and time columns
data = data.drop(columns=['YYYY-MM-DD', 'value'])

# Rename the remaining column
data.columns = ['Value', 'DateTime']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YYYY-MM-DD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import pandas as pd

# Load the data (skipping the first 36 lines as before)
file_path = 'GRDC_myanmar[Water_Discharge]/GRDC_myanmar/2260100_Q_Day.Cmd.txt'
data = pd.read_csv(file_path, delimiter=';', skiprows=36, encoding='ISO-8859-1')

# Print the column names to inspect them
print(data.columns)
# Out:
# Index(['YYYY-MM-DD', 'hh:mm', 'Value'], dtype='object')

# %% [markdown]
# ## Chindwin river [station:hktami]

# %%
import pandas as pd

file_path = 'GRDC_myanmar[Water_Discharge]/GRDC_myanmar/2260100_Q_Day.Cmd.txt'
data = pd.read_csv(file_path, delimiter=';', skiprows=36, encoding='ISO-8859-1')

data['hh:mm'] = data['hh:mm'].replace('--:--', '00:00')

data['DateTime'] = pd.to_datetime(data['YYYY-MM-DD'] + ' ' + data['hh:mm'], dayfirst=True, errors='coerce')


data = data.drop(columns=['YYYY-MM-DD', 'hh:mm'])


data.columns = ['Value', 'DateTime']


import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot
sns.lineplot(x='DateTime', y='Value', data=data)

# Add labels and a title
plt.xlabel('Date')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Water Discharge Over Time')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a histogram to visualize the distribution of water discharge values
sns.histplot(data['Value'], bins=30, kde=True)

# Add labels and a title
plt.xlabel('Water Discharge (m³/s)')
plt.ylabel('Frequency')
plt.title('Distribution of Water Discharge Values')

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by month, calculating the mean water discharge for each month
monthly_data = data.resample('ME', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled monthly data
sns.lineplot(x=monthly_data.index, y='Value', data=monthly_data)

# Add labels and a title
plt.xlabel('Month')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Monthly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by year, calculating the mean water discharge for each year
yearly_data = data.resample('YE', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled yearly data
sns.lineplot(x=yearly_data.index, y='Value', data=yearly_data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Yearly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Create a new column for the year
data['Year'] = data['DateTime'].dt.year

# Set the figure size
plt.figure(figsize=(12, 6))

# Create a boxplot to visualize the yearly variations in water discharge
sns.boxplot(x='Year', y='Value', data=data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Yearly Water Discharge Variations')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##  GRDC-No.:              2260110  River:                 CHINDWIN RIVER Station:               MAWLAIK

# %%
import pandas as pd

file_path = 'GRDC_myanmar[Water_Discharge]/GRDC_myanmar/2260110_Q_Day.Cmd.txt'
data = pd.read_csv(file_path, delimiter=';', skiprows=36, encoding='ISO-8859-1')

data['hh:mm'] = data['hh:mm'].replace('--:--', '00:00')

data['DateTime'] = pd.to_datetime(data['YYYY-MM-DD'] + ' ' + data['hh:mm'], dayfirst=True, errors='coerce')

data = data.drop(columns=['YYYY-MM-DD', 'hh:mm'])

data.columns = ['Value', 'DateTime']

import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot
sns.lineplot(x='DateTime', y='Value', data=data)

# Add labels and a title
plt.xlabel('Date')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Water Discharge Over Time')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a histogram to visualize the distribution of water discharge values
sns.histplot(data['Value'], bins=30, kde=True)

# Add labels and a title
plt.xlabel('Water Discharge (m³/s)')
plt.ylabel('Frequency')
plt.title('Distribution of Water Discharge Values')

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by month, calculating the mean water discharge for each month
monthly_data = data.resample('ME', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled monthly data
sns.lineplot(x=monthly_data.index, y='Value', data=monthly_data)

# Add labels and a title
plt.xlabel('Month')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Monthly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by year, calculating the mean water discharge for each year
yearly_data = data.resample('YE', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled yearly data
sns.lineplot(x=yearly_data.index, y='Value', data=yearly_data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Yearly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Create a new column for the year
data['Year'] = data['DateTime'].dt.year

# Set the figure size
plt.figure(figsize=(12, 6))

# Create a boxplot to visualize the yearly variations in water discharge
sns.boxplot(x='Year', y='Value', data=data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Yearly Water Discharge Variations')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## GRDC-No.:              2260120 River:                 CHINDWIN RIVER Station:               MONYWA

# %%
import pandas as pd

file_path = 'GRDC_myanmar[Water_Discharge]/GRDC_myanmar/2260120_Q_Day.Cmd.txt'
data = pd.read_csv(file_path, delimiter=';', skiprows=36, encoding='ISO-8859-1')

data['hh:mm'] = data['hh:mm'].replace('--:--', '00:00')

data['DateTime'] = pd.to_datetime(data['YYYY-MM-DD'] + ' ' + data['hh:mm'], dayfirst=True, errors='coerce')

data = data.drop(columns=['YYYY-MM-DD', 'hh:mm'])

data.columns = ['Value', 'DateTime']

import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot
sns.lineplot(x='DateTime', y='Value', data=data)

# Add labels and a title
plt.xlabel('Date')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Water Discharge Over Time')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a histogram to visualize the distribution of water discharge values
sns.histplot(data['Value'], bins=30, kde=True)

# Add labels and a title
plt.xlabel('Water Discharge (m³/s)')
plt.ylabel('Frequency')
plt.title('Distribution of Water Discharge Values')

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by month, calculating the mean water discharge for each month
monthly_data = data.resample('ME', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled monthly data
sns.lineplot(x=monthly_data.index, y='Value', data=monthly_data)

# Add labels and a title
plt.xlabel('Month')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Monthly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by year, calculating the mean water discharge for each year
yearly_data = data.resample('YE', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled yearly data
sns.lineplot(x=yearly_data.index, y='Value', data=yearly_data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Yearly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Create a new column for the year
data['Year'] = data['DateTime'].dt.year

# Set the figure size
plt.figure(figsize=(12, 6))

# Create a boxplot to visualize the yearly variations in water discharge
sns.boxplot(x='Year', y='Value', data=data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Yearly Water Discharge Variations')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

file_path = 'GRDC_myanmar[Water_Discharge]/GRDC_myanmar/2260400_Q_Day.Cmd.txt'
data = pd.read_csv(file_path, delimiter=';', skiprows=36, encoding='ISO-8859-1')

data['hh:mm'] = data['hh:mm'].replace('--:--', '00:00')

data['DateTime'] = pd.to_datetime(data['YYYY-MM-DD'] + ' ' + data['hh:mm'], dayfirst=True, errors='coerce')

data = data.drop(columns=['YYYY-MM-DD', 'hh:mm'])

data.columns = ['Value', 'DateTime']

import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot
sns.lineplot(x='DateTime', y='Value', data=data)

# Add labels and a title
plt.xlabel('Date')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Water Discharge Over Time')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a histogram to visualize the distribution of water discharge values
sns.histplot(data['Value'], bins=30, kde=True)

# Add labels and a title
plt.xlabel('Water Discharge (m³/s)')
plt.ylabel('Frequency')
plt.title('Distribution of Water Discharge Values')

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by month, calculating the mean water discharge for each month
monthly_data = data.resample('ME', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled monthly data
sns.lineplot(x=monthly_data.index, y='Value', data=monthly_data)

# Add labels and a title
plt.xlabel('Month')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Monthly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by year, calculating the mean water discharge for each year
yearly_data = data.resample('YE', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled yearly data
sns.lineplot(x=yearly_data.index, y='Value', data=yearly_data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Yearly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Create a new column for the year
data['Year'] = data['DateTime'].dt.year

# Set the figure size
plt.figure(figsize=(12, 6))

# Create a boxplot to visualize the yearly variations in water discharge
sns.boxplot(x='Year', y='Value', data=data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Yearly Water Discharge Variations')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

file_path = 'GRDC_myanmar[Water_Discharge]/GRDC_myanmar/2260400_Q_Day.Cmd.txt'
data = pd.read_csv(file_path, delimiter=';', skiprows=36, encoding='ISO-8859-1')

data['hh:mm'] = data['hh:mm'].replace('--:--', '00:00')

data['DateTime'] = pd.to_datetime(data['YYYY-MM-DD'] + ' ' + data['hh:mm'], dayfirst=True, errors='coerce')

data = data.drop(columns=['YYYY-MM-DD', 'hh:mm'])

data.columns = ['Value', 'DateTime']

import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot
sns.lineplot(x='DateTime', y='Value', data=data)

# Add labels and a title
plt.xlabel('Date')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Water Discharge Over Time')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a histogram to visualize the distribution of water discharge values
sns.histplot(data['Value'], bins=30, kde=True)

# Add labels and a title
plt.xlabel('Water Discharge (m³/s)')
plt.ylabel('Frequency')
plt.title('Distribution of Water Discharge Values')

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by month, calculating the mean water discharge for each month
monthly_data = data.resample('ME', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled monthly data
sns.lineplot(x=monthly_data.index, y='Value', data=monthly_data)

# Add labels and a title
plt.xlabel('Month')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Monthly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by year, calculating the mean water discharge for each year
yearly_data = data.resample('YE', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled yearly data
sns.lineplot(x=yearly_data.index, y='Value', data=yearly_data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Yearly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Create a new column for the year
data['Year'] = data['DateTime'].dt.year

# Set the figure size
plt.figure(figsize=(12, 6))

# Create a boxplot to visualize the yearly variations in water discharge
sns.boxplot(x='Year', y='Value', data=data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Yearly Water Discharge Variations')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

file_path = 'GRDC_myanmar[Water_Discharge]/GRDC_myanmar/2260400_Q_Day.Cmd.txt'
data = pd.read_csv(file_path, delimiter=';', skiprows=36, encoding='ISO-8859-1')

data['hh:mm'] = data['hh:mm'].replace('--:--', '00:00')

data['DateTime'] = pd.to_datetime(data['YYYY-MM-DD'] + ' ' + data['hh:mm'], dayfirst=True, errors='coerce')

data = data.drop(columns=['YYYY-MM-DD', 'hh:mm'])

data.columns = ['Value', 'DateTime']

import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot
sns.lineplot(x='DateTime', y='Value', data=data)

# Add labels and a title
plt.xlabel('Date')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Water Discharge Over Time')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a histogram to visualize the distribution of water discharge values
sns.histplot(data['Value'], bins=30, kde=True)

# Add labels and a title
plt.xlabel('Water Discharge (m³/s)')
plt.ylabel('Frequency')
plt.title('Distribution of Water Discharge Values')

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by month, calculating the mean water discharge for each month
monthly_data = data.resample('ME', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled monthly data
sns.lineplot(x=monthly_data.index, y='Value', data=monthly_data)

# Add labels and a title
plt.xlabel('Month')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Monthly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by year, calculating the mean water discharge for each year
yearly_data = data.resample('YE', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled yearly data
sns.lineplot(x=yearly_data.index, y='Value', data=yearly_data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Yearly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Create a new column for the year
data['Year'] = data['DateTime'].dt.year

# Set the figure size
plt.figure(figsize=(12, 6))

# Create a boxplot to visualize the yearly variations in water discharge
sns.boxplot(x='Year', y='Value', data=data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Yearly Water Discharge Variations')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # GRDC-No.:              2260500 River:                 IRRAWADDY RIVER Station:               SAGAING

# %%
import pandas as pd

file_path = 'GRDC_myanmar[Water_Discharge]/GRDC_myanmar/2260500_Q_Day.Cmd.txt'
data = pd.read_csv(file_path, delimiter=';', skiprows=36, encoding='ISO-8859-1')

data['hh:mm'] = data['hh:mm'].replace('--:--', '00:00')

data['DateTime'] = pd.to_datetime(data['YYYY-MM-DD'] + ' ' + data['hh:mm'], dayfirst=True, errors='coerce')

data = data.drop(columns=['YYYY-MM-DD', 'hh:mm'])

data.columns = ['Value', 'DateTime']

import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot
sns.lineplot(x='DateTime', y='Value', data=data)

# Add labels and a title
plt.xlabel('Date')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Water Discharge Over Time')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a histogram to visualize the distribution of water discharge values
sns.histplot(data['Value'], bins=30, kde=True)

# Add labels and a title
plt.xlabel('Water Discharge (m³/s)')
plt.ylabel('Frequency')
plt.title('Distribution of Water Discharge Values')

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by month, calculating the mean water discharge for each month
monthly_data = data.resample('ME', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled monthly data
sns.lineplot(x=monthly_data.index, y='Value', data=monthly_data)

# Add labels and a title
plt.xlabel('Month')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Monthly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by year, calculating the mean water discharge for each year
yearly_data = data.resample('YE', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled yearly data
sns.lineplot(x=yearly_data.index, y='Value', data=yearly_data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Yearly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Create a new column for the year
data['Year'] = data['DateTime'].dt.year

# Set the figure size
plt.figure(figsize=(12, 6))

# Create a boxplot to visualize the yearly variations in water discharge
sns.boxplot(x='Year', y='Value', data=data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Yearly Water Discharge Variations')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## GRDC-No.:              2260600 River:                 IRRAWADDY RIVER Station:               MAGWAY

# %%
import pandas as pd

file_path = 'GRDC_myanmar[Water_Discharge]/GRDC_myanmar/2260600_Q_Day.Cmd.txt'
data = pd.read_csv(file_path, delimiter=';', skiprows=36, encoding='ISO-8859-1')

data['hh:mm'] = data['hh:mm'].replace('--:--', '00:00')

data['DateTime'] = pd.to_datetime(data['YYYY-MM-DD'] + ' ' + data['hh:mm'], dayfirst=True, errors='coerce')

data = data.drop(columns=['YYYY-MM-DD', 'hh:mm'])

data.columns = ['Value', 'DateTime']

import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot
sns.lineplot(x='DateTime', y='Value', data=data)

# Add labels and a title
plt.xlabel('Date')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Water Discharge Over Time')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a histogram to visualize the distribution of water discharge values
sns.histplot(data['Value'], bins=30, kde=True)

# Add labels and a title
plt.xlabel('Water Discharge (m³/s)')
plt.ylabel('Frequency')
plt.title('Distribution of Water Discharge Values')

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by month, calculating the mean water discharge for each month
monthly_data = data.resample('ME', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled monthly data
sns.lineplot(x=monthly_data.index, y='Value', data=monthly_data)

# Add labels and a title
plt.xlabel('Month')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Monthly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by year, calculating the mean water discharge for each year
yearly_data = data.resample('YE', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled yearly data
sns.lineplot(x=yearly_data.index, y='Value', data=yearly_data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Yearly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Create a new column for the year
data['Year'] = data['DateTime'].dt.year

# Set the figure size
plt.figure(figsize=(12, 6))

# Create a boxplot to visualize the yearly variations in water discharge
sns.boxplot(x='Year', y='Value', data=data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Yearly Water Discharge Variations')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## GRDC-No.:              2260700 River:                 IRRAWADDY RIVER Station:               PYAY

# %%
import pandas as pd

file_path = 'GRDC_myanmar[Water_Discharge]/GRDC_myanmar/2260700_Q_Day.Cmd.txt'
data = pd.read_csv(file_path, delimiter=';', skiprows=36, encoding='ISO-8859-1')

data['hh:mm'] = data['hh:mm'].replace('--:--', '00:00')

data['DateTime'] = pd.to_datetime(data['YYYY-MM-DD'] + ' ' + data['hh:mm'], dayfirst=True, errors='coerce')

data = data.drop(columns=['YYYY-MM-DD', 'hh:mm'])

data.columns = ['Value', 'DateTime']

import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot
sns.lineplot(x='DateTime', y='Value', data=data)

# Add labels and a title
plt.xlabel('Date')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Water Discharge Over Time')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a histogram to visualize the distribution of water discharge values
sns.histplot(data['Value'], bins=30, kde=True)

# Add labels and a title
plt.xlabel('Water Discharge (m³/s)')
plt.ylabel('Frequency')
plt.title('Distribution of Water Discharge Values')

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by month, calculating the mean water discharge for each month
monthly_data = data.resample('ME', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled monthly data
sns.lineplot(x=monthly_data.index, y='Value', data=monthly_data)

# Add labels and a title
plt.xlabel('Month')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Monthly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Resample data by year, calculating the mean water discharge for each year
yearly_data = data.resample('YE', on='DateTime').mean()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a time series plot for the resampled yearly data
sns.lineplot(x=yearly_data.index, y='Value', data=yearly_data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Mean Water Discharge (m³/s)')
plt.title('Average Yearly Water Discharge')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# Create a new column for the year
data['Year'] = data['DateTime'].dt.year

# Set the figure size
plt.figure(figsize=(12, 6))

# Create a boxplot to visualize the yearly variations in water discharge
sns.boxplot(x='Year', y='Value', data=data)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Water Discharge (m³/s)')
plt.title('Yearly Water Discharge Variations')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.tight_layout()
plt.show()
